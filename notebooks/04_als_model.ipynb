# %%
from pyspark.sql import functions as F

df = spark.table("gold_fact_ratings")

df.show(5)
# Out:
# +------+-------+------+---------+-------------------+-----------+
# |userId|movieId|rating|timestamp|       timestamp_ts|rating_date|
# +------+-------+------+---------+-------------------+-----------+
# |   236|   2718|   3.0|943015211|1999-11-19 12:40:11| 1999-11-19|
# |   236|   2542|   5.0|943015062|1999-11-19 12:37:42| 1999-11-19|
# |   236|   2459|   4.0|943013896|1999-11-19 12:18:16| 1999-11-19|
# |   236|   2580|   5.0|943015701|1999-11-19 12:48:21| 1999-11-19|
# |   236|   1350|   4.0|943013896|1999-11-19 12:18:16| 1999-11-19|
# +------+-------+------+---------+-------------------+-----------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- timestamp_ts: timestamp (nullable = true)
#  |-- rating_date: date (nullable = true)

# %%
train, test = df.randomSplit([0.8, 0.2], seed=42)

# %%
from pyspark.ml.recommendation import ALS

# %%
als = ALS(
    userCol="userId",
    itemCol="movieId",
    ratingCol="rating",
    nonnegative=True,
    implicitPrefs=False,
    coldStartStrategy="drop",
    rank=10,
    maxIter=10,
    regParam=0.1
)

# %%
model = als.fit(train)

# %%
from pyspark.ml.evaluation import RegressionEvaluator

predictions = model.transform(test)

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse = evaluator.evaluate(predictions)

print("RMSE:", rmse)
# Out:
# RMSE: 0.7752334453818759

# %%
users = df.select("userId").distinct()

# %%
from pyspark.sql.functions import col

ratings = spark.table("gold_fact_ratings")

# %%
users = df.select("userId").distinct()
movies = df.select("movieId").distinct()

# %%
user_movie_pairs = users.crossJoin(movies)

# %%
candidates = (
    user_movie_pairs
    .join(ratings, ["userId", "movieId"], "left_anti")
)

# %%
predictions = model.transform(candidates)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

window = Window.partitionBy("userId").orderBy(col("prediction").desc())

top_recs = (
    predictions
    .withColumn("rank", row_number().over(window))
    .filter(col("rank") <= 10)
    .drop("rank")
)

# %%
top_recs.write.mode("overwrite").saveAsTable("gold_user_recommendations")

# %%
print(model)
# Out:
# ALSModel: uid=ALS_a6e201edc16d, rank=10

# %%
df_movies = spark.table("silver_dim_movies_enriched")

recs_with_titles = top_recs.join(
    df_movies.select("movieId", "title"),
    "movieId",
    "left"
)

recs_with_titles.show(20, truncate=False)
# Out:
# +-------+------+----------+-----------------------------------------------------------+
# |movieId|userId|prediction|title                                                      |
# +-------+------+----------+-----------------------------------------------------------+
# |3379   |1     |5.8383117 |On the Beach (1959)                                        |
# |170355 |1     |5.8383117 |Mulholland Dr. (1999)                                      |
# |33649  |1     |5.816472  |Saving Face (2004)                                         |
# |132333 |1     |5.691397  |Seve (2014)                                                |
# |5490   |1     |5.691397  |The Big Bus (1976)                                         |
# |3653   |1     |5.611389  |Endless Summer, The (1966)                                 |
# |27523  |1     |5.5818534 |My Sassy Girl (Yeopgijeogin geunyeo) (2001)                |
# |84847  |1     |5.568922  |Emma (2009)                                                |
# |171495 |1     |5.558476  |Cosmos                                                     |
# |87234  |1     |5.5363564 |Submarine (2010)                                           |
# |33649  |2     |5.04329   |Saving Face (2004)                                         |
# |89904  |2     |4.9013953 |The Artist (2011)                                          |
# |5466   |2     |4.8418956 |My Wife is an Actress (Ma Femme est une Actrice) (2001)    |
# |80586  |2     |4.7242985 |Flipped (2010)                                             |
# |1361   |2     |4.712047  |Paradise Lost: The Child Murders at Robin Hood Hills (1996)|
# |84847  |2     |4.704122  |Emma (2009)                                                |
# |78836  |2     |4.673342  |Enter the Void (2009)                                      |
# |72171  |2     |4.673342  |Black Dynamite (2009)                                      |
# |4256   |2     |4.673342  |Center of the World, The (2001)                            |
# |179135 |2     |4.673342  |Blue Planet II (2017)                                      |
# +-------+------+----------+-----------------------------------------------------------+
# only showing top 20 rows

# %%
tables = spark.catalog.listTables()
for t in tables:
    if t.name.startswith("gold_"):
        print(f"{t.name}  |  {t.tableType}  |  {t.isTemporary}")
# Out:
# gold_fact_ratings  |  MANAGED  |  False
# gold_power_users  |  MANAGED  |  False
# gold_user_recommendations  |  MANAGED  |  False

# %%
# Fact ratings
spark.table("gold_fact_ratings").show(5)
spark.table("gold_fact_ratings").count()

# Recommendations
spark.table("gold_user_recommendations").show(5, truncate=False)
spark.table("gold_user_recommendations").count()
# Out:
# +------+-------+------+----------+-------------------+-----------+
# |userId|movieId|rating| timestamp|       timestamp_ts|rating_date|
# +------+-------+------+----------+-------------------+-----------+
# |   249| 114074|   4.0|1425894202|2015-03-09 09:43:22| 2015-03-09|
# |   249| 129354|   4.5|1425894209|2015-03-09 09:43:29| 2015-03-09|
# |   236|   2718|   3.0| 943015211|1999-11-19 12:40:11| 1999-11-19|
# |   236|   2542|   5.0| 943015062|1999-11-19 12:37:42| 1999-11-19|
# |   236|   2459|   4.0| 943013896|1999-11-19 12:18:16| 1999-11-19|
# +------+-------+------+----------+-------------------+-----------+
# only showing top 5 rows
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |1     |3379   |5.8383117 |
# |1     |170355 |5.8383117 |
# |1     |33649  |5.816472  |
# |1     |132333 |5.691397  |
# |1     |5490   |5.691397  |
# +------+-------+----------+
# only showing top 5 rows
# 6100

# %%
from pyspark.sql import functions as F

spark.table("gold_fact_ratings") \
    .groupBy("movieId") \
    .agg(
        F.avg("rating").alias("avg_rating"),
        F.count("rating").alias("num_ratings")
    ) \
    .orderBy(F.desc("avg_rating"), F.desc("num_ratings")) \
    .show(10)
# Out:
# +-------+----------+-----------+
# |movieId|avg_rating|num_ratings|
# +-------+----------+-----------+
# |   6818|       5.0|          2|
# |   1151|       5.0|          2|
# |   6442|       5.0|          2|
# |  78836|       5.0|          2|
# |     53|       5.0|          2|
# |     99|       5.0|          2|
# |   3473|       5.0|          2|
# |  96608|       5.0|          1|
# |   3303|       5.0|          1|
# | 126921|       5.0|          1|
# +-------+----------+-----------+
# only showing top 10 rows

# %%
import mlflow

with mlflow.start_run():
    mlflow.log_param("rank", model.rank)
    mlflow.log_param("regParam", getattr(model, 'regParam', 'not available'))
    mlflow.log_metric("rmse", 0.8123190612289932)

# %%
model_path = "/FileStore/tables/movie-recommender-data-raw/gold_als_model"

# Remove trailing slash if it exists
model.write().overwrite().save(model_path)

print("Model saved successfully")
# Out:
# Model saved successfully

# %%
dbutils.fs.ls("/FileStore/tables/movie-recommender-data-raw/gold_als_model")
# Out:
# [FileInfo(path='dbfs:/FileStore/tables/movie-recommender-data-raw/gold_als_model/itemFactors/', name='itemFactors/', size=0, modificationTime=1771413193000),
#  FileInfo(path='dbfs:/FileStore/tables/movie-recommender-data-raw/gold_als_model/metadata/', name='metadata/', size=0, modificationTime=1771413191000),
#  FileInfo(path='dbfs:/FileStore/tables/movie-recommender-data-raw/gold_als_model/userFactors/', name='userFactors/', size=0, modificationTime=1771413192000)]

# %%
from pyspark.ml.recommendation import ALSModel

loaded_model = ALSModel.load("/FileStore/tables/movie-recommender-data-raw/gold_als_model")

print(loaded_model)
# Out:
# ALSModel: uid=ALS_a6e201edc16d, rank=10

# %%
from pyspark.sql.functions import count, desc

ratings = spark.table("gold_fact_ratings")

top_users = (
    ratings
    .groupBy("userId")
    .agg(count("*").alias("rating_count"))
    .orderBy(desc("rating_count"))
)

top_users.show(10)
# Out:
# +------+------------+
# |userId|rating_count|
# +------+------------+
# |   414|        2698|
# |   599|        2478|
# |   474|        2108|
# |   448|        1864|
# |   274|        1346|
# |   610|        1302|
# |    68|        1260|
# |   380|        1218|
# |   606|        1115|
# |   288|        1055|
# +------+------------+
# only showing top 10 rows

# %%
top_users.write.mode("overwrite").saveAsTable("gold_power_users")

# %%
tables = spark.catalog.listTables()
for t in tables:
    if t.name.startswith("gold_"):
        print(f"{t.name}  |  {t.tableType}  |  {t.isTemporary}")
# Out:
# gold_fact_ratings  |  MANAGED  |  False
# gold_power_users  |  MANAGED  |  False
# gold_user_recommendations  |  MANAGED  |  False

# %%
from pyspark.sql.functions import count, desc

recs = spark.table("gold_user_recommendations")

top_movies = (
    recs
    .groupBy("movieId")
    .agg(count("*").alias("recommendation_count"))
    .orderBy(desc("recommendation_count"))
)

top_movies.show(20)
# Out:
# +-------+--------------------+
# |movieId|recommendation_count|
# +-------+--------------------+
# | 170355|                 312|
# |   3379|                 304|
# |   7842|                 276|
# |  33649|                 255|
# |   1066|                 158|
# |  89904|                 140|
# |  72171|                 136|
# |  78836|                 132|
# |  60943|                 106|
# |   7096|                 106|
# |  84847|                 104|
# | 138966|                 104|
# | 179135|                 103|
# |   7841|                  99|
# |  59018|                  93|
# |   7748|                  89|
# |   4256|                  86|
# | 171495|                  85|
# |   6650|                  84|
# |   4495|                  76|
# +-------+--------------------+
# only showing top 20 rows

# %%
movies = spark.table("silver_dim_movies_enriched")

top_movies_with_titles = (
    top_movies
    .join(movies, "movieId", "left")
)

top_movies_with_titles.show(20)
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# |movieId|recommendation_count|               title|              genres|        genres_array| imdbId|tmdbId|actors|director|poster|
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# |   5222|                  14|Kissing Jessica S...|      Comedy|Romance|   [Comedy, Romance]|0264761| 15647|  NULL|    NULL|  NULL|
# |    611|                   1|Hellraiser: Blood...|Action|Horror|Sci-Fi|[Action, Horror, ...|0116514|  8766|  NULL|    NULL|  NULL|
# |   2936|                  15|Sullivan's Travel...|Adventure|Comedy|...|[Adventure, Comed...|0034240| 16305|  NULL|    NULL|  NULL|
# |  84273|                  27|Zeitgeist: Moving...|         Documentary|       [Documentary]|1781069| 54293|  NULL|    NULL|  NULL|
# |  51931|                  63|Reign Over Me (2007)|               Drama|             [Drama]|0490204|  2355|  NULL|    NULL|  NULL|
# | 107565|                   3|Fuck You, Goethe ...|              Comedy|            [Comedy]|2987732|233063|  NULL|    NULL|  NULL|
# |   7841|                  99|Children of Dune ...|      Fantasy|Sci-Fi|   [Fantasy, Sci-Fi]|0287839|192936|  NULL|    NULL|  NULL|
# |  26133|                   9|Charlie Brown Chr...|Animation|Childre...|[Animation, Child...|0059026| 13187|  NULL|    NULL|  NULL|
# |   3096|                   3|My Man Godfrey (1...|              Comedy|            [Comedy]|0050738| 52470|  NULL|    NULL|  NULL|
# |   5992|                   6|   Hours, The (2002)|       Drama|Romance|    [Drama, Romance]|0274558|   590|  NULL|    NULL|  NULL|
# |   3404|                   9|      Titanic (1953)|        Action|Drama|     [Action, Drama]|0046435| 16535|  NULL|    NULL|  NULL|
# |   6957|                   1|    Bad Santa (2003)|        Comedy|Crime|     [Comedy, Crime]|0307987| 10147|  NULL|    NULL|  NULL|
# |   7982|                  10|Tale of Two Siste...|Drama|Horror|Myst...|[Drama, Horror, M...|0365376|  4552|  NULL|    NULL|  NULL|
# |  93563|                   1|      Lockout (2012)|Action|Sci-Fi|Thr...|[Action, Sci-Fi, ...|1592525| 81796|  NULL|    NULL|  NULL|
# |   1250|                   1|Bridge on the Riv...| Adventure|Drama|War|[Adventure, Drama...|0050212|   826|  NULL|    NULL|  NULL|
# |  78836|                 132|Enter the Void (2...|               Drama|             [Drama]|1191111| 34647|  NULL|    NULL|  NULL|
# |  26865|                   6|Fist of Legend (J...|        Action|Drama|     [Action, Drama]|0110200| 17809|  NULL|    NULL|  NULL|
# |   3451|                  72|Guess Who's Comin...|               Drama|             [Drama]|0061735|  1879|  NULL|    NULL|  NULL|
# |   5137|                   1|      Scratch (2001)|         Documentary|       [Documentary]|0143861| 18984|  NULL|    NULL|  NULL|
# |  98279|                   5|Fantastic Fear of...|              Comedy|            [Comedy]|2006040|101519|  NULL|    NULL|  NULL|
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# only showing top 20 rows

# %%
top_movies_with_titles.show(5)
top_movies_with_titles.printSchema()
# Out:
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# |movieId|recommendation_count|               title|              genres|        genres_array| imdbId|tmdbId|actors|director|poster|
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# |   5222|                  14|Kissing Jessica S...|      Comedy|Romance|   [Comedy, Romance]|0264761| 15647|  NULL|    NULL|  NULL|
# |    611|                   1|Hellraiser: Blood...|Action|Horror|Sci-Fi|[Action, Horror, ...|0116514|  8766|  NULL|    NULL|  NULL|
# |   2936|                  15|Sullivan's Travel...|Adventure|Comedy|...|[Adventure, Comed...|0034240| 16305|  NULL|    NULL|  NULL|
# |  84273|                  27|Zeitgeist: Moving...|         Documentary|       [Documentary]|1781069| 54293|  NULL|    NULL|  NULL|
# |  51931|                  63|Reign Over Me (2007)|               Drama|             [Drama]|0490204|  2355|  NULL|    NULL|  NULL|
# +-------+--------------------+--------------------+--------------------+--------------------+-------+------+------+--------+------+
# only showing top 5 rows
# root
#  |-- movieId: integer (nullable = true)
#  |-- recommendation_count: long (nullable = false)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- genres_array: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- imdbId: string (nullable = true)
#  |-- tmdbId: string (nullable = true)
#  |-- actors: string (nullable = true)
#  |-- director: string (nullable = true)
#  |-- poster: string (nullable = true)

# %%
top_movies_with_titles.select("movieId", "title", "tmdbId").write.mode("overwrite").option("header", True).csv("/FileStore/tmp/top_movies_scrape.csv")

# %%
# Read the saved CSV into a DataFrame
df_check = spark.read.option("header", True).csv("/FileStore/tmp/top_movies_scrape.csv")
display(df_check.limit(10))  # Show first 10 rows
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movieId</th><th>title</th><th>tmdbId</th></tr></thead><tbody><tr><td>5222</td><td>Kissing Jessica Stein (2001)</td><td>15647</td></tr><tr><td>611</td><td>Hellraiser: Bloodline (1996)</td><td>8766</td></tr><tr><td>2936</td><td>Sullivan's Travels (1941)</td><td>16305</td></tr><tr><td>84273</td><td>Zeitgeist: Moving Forward (2011)</td><td>54293</td></tr><tr><td>51931</td><td>Reign Over Me (2007)</td><td>2355</td></tr><tr><td>107565</td><td>Fuck You, Goethe (Fack Ju Göhte) (2013)</td><td>233063</td></tr><tr><td>7841</td><td>Children of Dune (2003)</td><td>192936</td></tr><tr><td>26133</td><td>Charlie Brown Christmas, A (1965)</td><td>13187</td></tr><tr><td>3096</td><td>My Man Godfrey (1957)</td><td>52470</td></tr><tr><td>5992</td><td>Hours, The (2002)</td><td>590</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import desc

top_500_movies = top_movies_with_titles \
    .orderBy(desc("recommendation_count")) \
    .limit(500) \
    .select("movieId", "title", "tmdbId")

# %%
top_500_movies.coalesce(1).write.mode("overwrite").option("header", True).csv("/FileStore/tmp/top_500_movies.csv")

# https://adb-7405616516337746.6.azuredatabricks.net/files/tmp/top_500_movies.csv
# direct link for the created file from which it can be downloaded

# %%
files = dbutils.fs.ls("/FileStore/tmp/top_500_movies.csv")
csv_file = [f.path for f in files if f.name.endswith(".csv")][0]  # pick the part-00000 file

# Move to root for easy download
dbutils.fs.cp(csv_file, "/FileStore/top_500_movies_final.csv")
# Out:
# True

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
df_movies = spark.read.option("header", True).csv("/FileStore/tables/movie-recommender-data-raw/top_500_movies_scraped.csv")
df_movies.show(5)
# Out:
# +------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# |tmdbId|         title|              genres|release_date|            overview|runtime|vote_average|         poster_path|
# +------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# | 35412|  On the Beach|['Science Fiction...|  1959-12-17|In 1964, atomic w...|    134|       6.659|/lTDuj5zalrI0fpQe...|
# | 19316|   Saving Face|['Comedy', 'Roman...|  2004-09-12|A Chinese-America...|     97|       7.271|/7XbbgkKi4nEMOu9i...|
# | 31530|Shall We Dance|['Comedy', 'Roman...|  1937-05-07|Ballet star Petro...|    109|       7.264|/6anwn2NxTw7NwVEE...|
# | 74643|    The Artist|['Drama', 'Comedy...|  2011-10-12|Hollywood, 1927: ...|    100|       7.443|/A7zDHjlYPi1peLyB...|
# | 24804|Black Dynamite|['Comedy', 'Action']|  2009-10-16|This is the story...|     85|       7.097|/u3oWQDz0JggzzsVl...|
# +------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# only showing top 5 rows

# %%
df_movies.printSchema()
# Out:
# root
#  |-- tmdbId: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- overview: string (nullable = true)
#  |-- runtime: string (nullable = true)
#  |-- vote_average: string (nullable = true)
#  |-- poster_path: string (nullable = true)

# %%
from pyspark.sql.functions import col

df_movies = df_movies.withColumn("tmdbId", col("tmdbId").cast("int"))

# %%
df_ratings = spark.table("gold_fact_ratings")
df_links   = spark.table("gold_dim_movies")  # must contain movieId + tmdbId

df_movies_joined = df_links.join(
    df_movies,
    on="tmdbId",
    how="inner"
)

# %%
df_links = spark.read.option("header", True) \
    .csv("/FileStore/tables/movie-recommender-data-raw/links.csv")

df_links.printSchema()
# Out:
# root
#  |-- movieId: string (nullable = true)
#  |-- imdbId: string (nullable = true)
#  |-- tmdbId: string (nullable = true)

# %%
from pyspark.sql.functions import col

df_links = df_links \
    .withColumn("movieId", col("movieId").cast("int")) \
    .withColumn("tmdbId", col("tmdbId").cast("int"))

# %%
df_movies = df_movies.withColumn("tmdbId", col("tmdbId").cast("int"))

# %%
df_movies_enriched = df_links.join(
    df_movies,
    on="tmdbId",
    how="inner"
)

# %%
df_movies_enriched.write.mode("overwrite").saveAsTable("gold_dim_movies_enriched")

# %%
from pyspark.sql.functions import col

df_links = df_links \
    .withColumn("movieId", col("movieId").cast("int")) \
    .withColumn("tmdbId", col("tmdbId").cast("int"))

df_movies = df_movies.withColumn("tmdbId", col("tmdbId").cast("int"))

df_movies_enriched = df_links.join(
    df_movies,
    on="tmdbId",
    how="inner"
)

df_movies_enriched.show(5)
# Out:
# +------+-------+-------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# |tmdbId|movieId| imdbId|         title|              genres|release_date|            overview|runtime|vote_average|         poster_path|
# +------+-------+-------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# | 35412|   3379|0053137|  On the Beach|['Science Fiction...|  1959-12-17|In 1964, atomic w...|    134|       6.659|/lTDuj5zalrI0fpQe...|
# | 19316|  33649|0384504|   Saving Face|['Comedy', 'Roman...|  2004-09-12|A Chinese-America...|     97|       7.271|/7XbbgkKi4nEMOu9i...|
# | 31530|   1066|0029546|Shall We Dance|['Comedy', 'Roman...|  1937-05-07|Ballet star Petro...|    109|       7.264|/6anwn2NxTw7NwVEE...|
# | 74643|  89904|1655442|    The Artist|['Drama', 'Comedy...|  2011-10-12|Hollywood, 1927: ...|    100|       7.443|/A7zDHjlYPi1peLyB...|
# | 24804|  72171|1190536|Black Dynamite|['Comedy', 'Action']|  2009-10-16|This is the story...|     85|       7.097|/u3oWQDz0JggzzsVl...|
# +------+-------+-------+--------------+--------------------+------------+--------------------+-------+------------+--------------------+
# only showing top 5 rows

# %%
tables = spark.catalog.listTables()
for t in tables:
    if t.name.startswith("gold_"):
        print(f"{t.name}  |  {t.tableType}  |  {t.isTemporary}")
# Out:
# gold_dim_movies_enriched  |  MANAGED  |  False
# gold_fact_ratings  |  MANAGED  |  False
# gold_power_users  |  MANAGED  |  False
# gold_user_recommendations  |  MANAGED  |  False

# %%
ratings = spark.table("gold_fact_ratings")
ratings.printSchema()
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- rating: float (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- timestamp_ts: timestamp (nullable = true)
#  |-- rating_date: date (nullable = true)

# %%
from pyspark.ml.recommendation import ALS

ratings = spark.table("gold_fact_ratings")

train, test = ratings.randomSplit([0.8, 0.2], seed=42)

als = ALS(
    userCol="userId",
    itemCol="movieId",
    ratingCol="rating",
    rank=10,
    maxIter=10,
    regParam=0.1,
    coldStartStrategy="drop"
)

model = als.fit(train)

# %%
user_recs = model.recommendForAllUsers(10)

# %%
ratings = spark.table("gold_fact_ratings")

users = ratings.select("userId").distinct()

# %%
user_recs = model.recommendForUserSubset(users, 10)

# %%
ratings = spark.table("gold_fact_ratings")

users = ratings.select("userId").distinct()
movies = ratings.select("movieId").distinct()

user_movie_pairs = users.crossJoin(movies)

# %%
predictions = model.transform(user_movie_pairs)

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number, col

window_spec = Window.partitionBy("userId").orderBy(col("prediction").desc())

top10 = predictions.withColumn(
    "rank",
    row_number().over(window_spec)
).filter("rank <= 10").drop("rank")

top10.show(5)
# Out:
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |     1|   3379| 5.8713207|
# |     1| 170355| 5.8713207|
# |     1|  33649|  5.712371|
# |     1| 171495| 5.5977917|
# |     1|   6442|  5.506807|
# +------+-------+----------+
# only showing top 5 rows

# %%
top10.write.mode("overwrite") \
    .saveAsTable("gold_user_recommendations_flat")

# %%
tables = spark.catalog.listTables()
for t in tables:
    if t.name.startswith("gold_"):
        print(f"{t.name}  |  {t.tableType}  |  {t.isTemporary}")
# Out:
# gold_dim_movies_enriched  |  MANAGED  |  False
# gold_fact_ratings  |  MANAGED  |  False
# gold_power_users  |  MANAGED  |  False
# gold_user_recommendations  |  MANAGED  |  False
# gold_user_recommendations_flat  |  MANAGED  |  False

# %%
from pyspark.ml.evaluation import RegressionEvaluator

predictions = model.transform(test)

evaluator = RegressionEvaluator(
    metricName="rmse",
    labelCol="rating",
    predictionCol="prediction"
)

rmse = evaluator.evaluate(predictions)
print("RMSE:", rmse)
# Out:
# RMSE: 0.7977473495200248

# %%
spark.table("gold_user_recommendations_flat").printSchema()
spark.table("gold_user_recommendations_flat").show(5)
# Out:
# root
#  |-- userId: integer (nullable = true)
#  |-- movieId: integer (nullable = true)
#  |-- prediction: float (nullable = true)
#
# +------+-------+----------+
# |userId|movieId|prediction|
# +------+-------+----------+
# |     1|   3379| 5.8713207|
# |     1| 170355| 5.8713207|
# |     1|  33649|  5.712371|
# |     1| 171495| 5.5977917|
# |     1|   6442|  5.506807|
# +------+-------+----------+
# only showing top 5 rows

# %%
recs = spark.table("gold_user_recommendations_flat")
movies = spark.table("gold_dim_movies_enriched")

final_recs = recs.join(
    movies,
    on="movieId",
    how="left"
)

# %%
final_recs.write.mode("overwrite") \
    .saveAsTable("gold_user_recommendations_enriched")

# %%
tables = spark.catalog.listTables()
for t in tables:
    if t.name.startswith("gold_"):
        print(f"{t.name}  |  {t.tableType}  |  {t.isTemporary}")
# Out:
# gold_dim_movies_enriched  |  MANAGED  |  False
# gold_fact_ratings  |  MANAGED  |  False
# gold_power_users  |  MANAGED  |  False
# gold_user_recommendations  |  MANAGED  |  False
# gold_user_recommendations_enriched  |  MANAGED  |  False
# gold_user_recommendations_flat  |  MANAGED  |  False

# %%
spark.sql("""
SELECT userId, title, genres, prediction
FROM gold_user_recommendations_enriched
WHERE userId = 1
ORDER BY prediction DESC
""").show(10, False)
# Out:
# +------+-------------------------+---------------------------------------+----------+
# |userId|title                    |genres                                 |prediction|
# +------+-------------------------+---------------------------------------+----------+
# |1     |On the Beach             |['Science Fiction', 'Drama', 'Romance']|5.8713207 |
# |1     |NULL                     |NULL                                   |5.8713207 |
# |1     |Saving Face              |['Comedy', 'Romance', 'Drama']         |5.712371  |
# |1     |NULL                     |NULL                                   |5.5977917 |
# |1     |Belle Époque             |['Comedy', 'Drama', 'Romance']         |5.506807  |
# |1     |My Sassy Girl            |['Drama', 'Comedy', 'Romance']         |5.4446435 |
# |1     |Enter the Void           |['Fantasy', 'Drama']                   |5.42667   |
# |1     |Black Dynamite           |['Comedy', 'Action']                   |5.42667   |
# |1     |Nasu: Summer in Andalusia|['Animation', 'Action']                |5.42667   |
# |1     |NULL                     |NULL                                   |5.42667   |
# +------+-------------------------+---------------------------------------+----------+

# %%
final_recs_clean = recs.join(
    movies,
    on="movieId",
    how="inner"  # only keep matches
)

# %%
# Assuming `final_recs_clean` is the joined DataFrame from Option A
# with movieId, userId, prediction, title, genres

# Save as managed table in your GOLD schema
final_recs_clean.write.mode("overwrite").saveAsTable("gold_user_recommendations_enriched")

# Verify
spark.table("gold_user_recommendations_enriched").show(10, truncate=False)
# Out:
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+
# |movieId|userId|prediction|tmdbId|imdbId |title                    |genres                                 |release_date|overview                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |runtime|vote_average|poster_path                     |
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+
# |3379   |610   |5.58077   |35412 |0053137|On the Beach             |['Science Fiction', 'Drama', 'Romance']|1959-12-17  |In 1964, atomic war wipes out humanity in the northern hemisphere; one American submarine finds temporary safe haven in Australia, where life-as-usual covers growing despair. In denial about the loss of his wife and children in the holocaust, American Captain Towers meets careworn but gorgeous Moira Davidson, who begins to fall for him. The sub returns after reconnaissance a month (or less) before the end; will Towers and Moira find comfort with each other?|134    |6.659       |/lTDuj5zalrI0fpQel7UfPHTexTK.jpg|
# |33649  |610   |5.109606  |19316 |0384504|Saving Face              |['Comedy', 'Romance', 'Drama']         |2004-09-12  |A Chinese-American lesbian and her traditionalist mother are reluctant to go public with secret loves that clash against cultural expectations.                                                                                                                                                                                                                                                                                                                              |97     |7.271       |/7XbbgkKi4nEMOu9iwiANXpjKKhe.jpg|
# |1066   |609   |4.153519  |31530 |0029546|Shall We Dance           |['Comedy', 'Romance']                  |1937-05-07  |Ballet star Petrov arranges to cross the Atlantic aboard the same ship as the dancer and musical star he's fallen for but barely knows. By the time the ocean liner reaches New York, a little white lie has churned through the rumour mill and turned into a hot gossip item—that the two celebrities are secretly married.                                                                                                                                                |109    |7.264       |/6anwn2NxTw7NwVEEU4qhVwN3Exi.jpg|
# |89904  |609   |4.1482706 |74643 |1655442|The Artist               |['Drama', 'Comedy', 'Romance']         |2011-10-12  |Hollywood, 1927: As silent movie star George Valentin wonders if the arrival of talking pictures will cause him to fade into oblivion, he sparks with Peppy Miller, a young dancer set for a big break.                                                                                                                                                                                                                                                                      |100    |7.443       |/A7zDHjlYPi1peLyBlite9xhePky.jpg|
# |72171  |604   |4.550439  |24804 |1190536|Black Dynamite           |['Comedy', 'Action']                   |2009-10-16  |This is the story of 1970s African-American action legend Black Dynamite. The Man killed his brother, pumped heroin into local orphanages, and flooded the ghetto with adulterated malt liquor. Black Dynamite was the one hero willing to fight The Man all the way from the blood-soaked city streets to the hallowed halls of the Honky House.                                                                                                                            |85     |7.097       |/u3oWQDz0JggzzsVlsuHY7XVxp5Y.jpg|
# |78836  |601   |5.0168896 |34647 |1191111|Enter the Void           |['Fantasy', 'Drama']                   |2010-05-05  |This psychedelic tour of life after death is seen entirely from the point of view of Oscar, a young American drug dealer and addict living in Tokyo with his prostitute sister, Linda. When Oscar is killed by police during a bust gone bad, his spirit journeys from the past -- where he sees his parents before their deaths -- to the present -- where he witnesses his own autopsy -- and then to the future, where he looks out for his sister from beyond the grave. |161    |7.299       |/krKnsfvSJM1PL40tLicRhVQ6kuG.jpg|
# |60943  |608   |4.873039  |10183 |0978759|Frozen River             |['Drama', 'Crime']                     |2008-03-26  |After her husband deserts her, working-class mother Ray Eddy is in great need of money to find a home. Lured by the possibility of easy cash, she joins Lila, a widowed Mohawk who earns a living by smuggling immigrants from Canada to the U.S. across the St. Lawrence.                                                                                                                                                                                                   |97     |6.613       |/qZRcN4JLwYQWTxKlycZPLQb37mO.jpg|
# |7096   |610   |5.110932  |30140 |0307385|Rivers and Tides         |['Documentary']                        |2001-02-13  |Portrait of Andy Goldsworthy, an artist whose specialty is ephemeral sculptures made from elements of nature.                                                                                                                                                                                                                                                                                                                                                                |90     |7.3         |/6KmRx9auUqQ2bHCPGi32TS5VSYh.jpg|
# |138966 |601   |5.0168896 |60843 |0382868|Nasu: Summer in Andalusia|['Animation', 'Action']                |2003-06-26  |Pepe Benengeli is a second-class cyclist, only there to support the star member of the team. This summer he is participating in the Tour of Spain, which passes through the streets of his hometown of Andalusia. In a coincidence, his brother and ex-girlfriend are getting married on the same day as the climax of the race. Pepe, who left his hometown after suffering a breakdown, is determined to achieve something special on this day.                            |47     |7.1         |/jjDMsdZtGlIbmS1jUVnsCh1VjVi.jpg|
# |59018  |608   |4.873039  |12473 |0857191|The Visitor              |['Crime', 'Drama', 'Music']            |2008-02-21  |A college professor travels to New York City to attend a conference and finds a young couple living in his apartment.                                                                                                                                                                                                                                                                                                                                                        |104    |7.133       |/9XRRSD7swlYrGBhZ8vOR2yngIKZ.jpg|
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+
# only showing top 10 rows

# %%
spark.sql("""
SELECT userId, title, genres, prediction
FROM gold_user_recommendations_enriched
WHERE userId = 1
ORDER BY prediction DESC
""").show(10, False)
# Out:
# +------+-------------------------+---------------------------------------+----------+
# |userId|title                    |genres                                 |prediction|
# +------+-------------------------+---------------------------------------+----------+
# |1     |On the Beach             |['Science Fiction', 'Drama', 'Romance']|5.8713207 |
# |1     |Saving Face              |['Comedy', 'Romance', 'Drama']         |5.712371  |
# |1     |Belle Époque             |['Comedy', 'Drama', 'Romance']         |5.506807  |
# |1     |My Sassy Girl            |['Drama', 'Comedy', 'Romance']         |5.4446435 |
# |1     |Nasu: Summer in Andalusia|['Animation', 'Action']                |5.42667   |
# |1     |Enter the Void           |['Fantasy', 'Drama']                   |5.42667   |
# |1     |Black Dynamite           |['Comedy', 'Action']                   |5.42667   |
# +------+-------------------------+---------------------------------------+----------+

# %%
# Total recommendations
spark.table("gold_user_recommendations_enriched").count()

# Check for any missing titles or genres
spark.table("gold_user_recommendations_enriched") \
     .filter("title IS NULL OR genres IS NULL") \
     .count()
# Out:
# 0

# %%
spark.table("gold_user_recommendations_enriched") \
     .filter("userId = 1") \
     .orderBy("prediction", ascending=False) \
     .show(10, truncate=False)
# Out:
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+
# |movieId|userId|prediction|tmdbId|imdbId |title                    |genres                                 |release_date|overview                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |runtime|vote_average|poster_path                     |
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+
# |3379   |1     |5.8713207 |35412 |0053137|On the Beach             |['Science Fiction', 'Drama', 'Romance']|1959-12-17  |In 1964, atomic war wipes out humanity in the northern hemisphere; one American submarine finds temporary safe haven in Australia, where life-as-usual covers growing despair. In denial about the loss of his wife and children in the holocaust, American Captain Towers meets careworn but gorgeous Moira Davidson, who begins to fall for him. The sub returns after reconnaissance a month (or less) before the end; will Towers and Moira find comfort with each other?|134    |6.659       |/lTDuj5zalrI0fpQel7UfPHTexTK.jpg|
# |33649  |1     |5.712371  |19316 |0384504|Saving Face              |['Comedy', 'Romance', 'Drama']         |2004-09-12  |A Chinese-American lesbian and her traditionalist mother are reluctant to go public with secret loves that clash against cultural expectations.                                                                                                                                                                                                                                                                                                                              |97     |7.271       |/7XbbgkKi4nEMOu9iwiANXpjKKhe.jpg|
# |6442   |1     |5.506807  |2470  |0103791|Belle Époque             |['Comedy', 'Drama', 'Romance']         |1992-12-04  |In 1931, a young soldier deserts from the army and falls into a country farm, where he is welcomed by the owner due to his political ideas. Manolo has four daughters, Fernando likes all of them and they like him, so he has to decide which one to love.                                                                                                                                                                                                                  |109    |6.639       |/2pb7i9pI6wMH5dlyjbVTXdfSKun.jpg|
# |27523  |1     |5.4446435 |11178 |0293715|My Sassy Girl            |['Drama', 'Comedy', 'Romance']         |2001-07-27  |A dweeby, mild-mannered man comes to the aid of a drunk young woman on a subway platform. Little does he know how much trouble he’s in for.                                                                                                                                                                                                                                                                                                                                  |137    |7.528       |/grFSgOnSt8saknfRUY05wLGVJ7T.jpg|
# |138966 |1     |5.42667   |60843 |0382868|Nasu: Summer in Andalusia|['Animation', 'Action']                |2003-06-26  |Pepe Benengeli is a second-class cyclist, only there to support the star member of the team. This summer he is participating in the Tour of Spain, which passes through the streets of his hometown of Andalusia. In a coincidence, his brother and ex-girlfriend are getting married on the same day as the climax of the race. Pepe, who left his hometown after suffering a breakdown, is determined to achieve something special on this day.                            |47     |7.1         |/jjDMsdZtGlIbmS1jUVnsCh1VjVi.jpg|
# |78836  |1     |5.42667   |34647 |1191111|Enter the Void           |['Fantasy', 'Drama']                   |2010-05-05  |This psychedelic tour of life after death is seen entirely from the point of view of Oscar, a young American drug dealer and addict living in Tokyo with his prostitute sister, Linda. When Oscar is killed by police during a bust gone bad, his spirit journeys from the past -- where he sees his parents before their deaths -- to the present -- where he witnesses his own autopsy -- and then to the future, where he looks out for his sister from beyond the grave. |161    |7.299       |/krKnsfvSJM1PL40tLicRhVQ6kuG.jpg|
# |72171  |1     |5.42667   |24804 |1190536|Black Dynamite           |['Comedy', 'Action']                   |2009-10-16  |This is the story of 1970s African-American action legend Black Dynamite. The Man killed his brother, pumped heroin into local orphanages, and flooded the ghetto with adulterated malt liquor. Black Dynamite was the one hero willing to fight The Man all the way from the blood-soaked city streets to the hallowed halls of the Honky House.                                                                                                                            |85     |7.097       |/u3oWQDz0JggzzsVlsuHY7XVxp5Y.jpg|
# +-------+------+----------+------+-------+-------------------------+---------------------------------------+------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------+------------+--------------------------------+

# %%
from pyspark.sql.functions import count, desc

spark.table("gold_user_recommendations_enriched") \
     .groupBy("movieId", "title") \
     .agg(count("*").alias("recommendation_count")) \
     .orderBy(desc("recommendation_count")) \
     .show(10, truncate=False)
# Out:
# +-------+-------------------------+--------------------+
# |movieId|title                    |recommendation_count|
# +-------+-------------------------+--------------------+
# |3379   |On the Beach             |322                 |
# |33649  |Saving Face              |192                 |
# |72171  |Black Dynamite           |144                 |
# |78836  |Enter the Void           |141                 |
# |138966 |Nasu: Summer in Andalusia|116                 |
# |4256   |The Center of the World  |111                 |
# |7096   |Rivers and Tides         |107                 |
# |5915   |Escape to Victory        |88                  |
# |132333 |Seve                     |75                  |
# |5490   |The Big Bus              |70                  |
# +-------+-------------------------+--------------------+
# only showing top 10 rows

# %%
spark.table("gold_user_recommendations_enriched") \
     .select("userId", "movieId", "title", "genres", "prediction") \
     .coalesce(1) \
     .write.mode("overwrite") \
     .option("header", True) \
     .csv("/FileStore/tables/movie-recommender/movie-recommender-final.csv")
